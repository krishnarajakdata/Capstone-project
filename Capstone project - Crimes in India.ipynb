# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\01_District_wise_crimes_committed_IPC_2001_2012.csv")

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0  ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1  ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2  ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3  ANDHRA PRADESH       CUDDAPAH  2001      80                 53
# 4  ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
#
#    CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                         17    50               0
# 1                                          1    23               0
# 2                                          2    27               0
# 3                                          1    20               0
# 4                                          1    23               0
#
#    OTHER RAPE  KIDNAPPING & ABDUCTION  ...  ARSON  HURT/GREVIOUS HURT  \
# 0          50                      46  ...     30                1131
# ...

# %%
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\02_01_District_wise_crimes_committed_against_SC_2001_2012.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\02_District_wise_crimes_committed_against_ST_2001_2012.csv")

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Murder  Rape  Kidnapping Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001       0     1                     2
# 1  ANDHRA PRADESH      ANANTAPUR  2001       0     0                     0
# 2  ANDHRA PRADESH       CHITTOOR  2001       0     0                     0
# 3  ANDHRA PRADESH       CUDDAPAH  2001       0     0                     0
# 4  ANDHRA PRADESH  EAST GODAVARI  2001       0     0                     0
#
#    Dacoity  Robbery  Arson  Hurt  Protection of Civil Rights (PCR) Act  \
# 0        0        0      0     2                                     0
# 1        0        0      0     7                                     0
# 2        0        0      0     2                                     0
# 3        0        0      0     2                                     0
# 4        0        0      0     0                                     0
#
#    Prevention of atrocities (POA) Act  Other Crimes Against STs
# ...

# %%
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\03_District_wise_crimes_committed_against_children_2001_2012.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\08_01_Juvenile_apprehended_state_IPC_2001_2010.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\11_Property_stolen_and_recovered_nature_of_property_2001_2010.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\13_Police_killed_or_injured_on_duty2001_2010.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\17_Case_reported_and_value_of_property_taken_away_by_place_of_occurrence_2001_2012.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\17_Crime_by_place_of_occurrence_2001_2012.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\35_Human_rights_violation_by_police_2001_2010.csv")
df = pd.read_csv(r"C:\Users\USER\OneDrive\Desktop\INDIA CRIME\India_Crime - Copy\42_District_wise_crimes_committed_against_women_2001_2012.csv")

# %%
df.head()
# Out:
#          STATE/UT       DISTRICT  Year  Rape  Kidnapping and Abduction  \
# 0  ANDHRA PRADESH       ADILABAD  2001    50                        30
# 1  ANDHRA PRADESH      ANANTAPUR  2001    23                        30
# 2  ANDHRA PRADESH       CHITTOOR  2001    27                        34
# 3  ANDHRA PRADESH       CUDDAPAH  2001    20                        20
# 4  ANDHRA PRADESH  EAST GODAVARI  2001    23                        26
#
#    Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            16                                                149
# 1             7                                                118
# 2            14                                                112
# 3            17                                                126
# 4            12                                                109
#
#    Insult to modesty of Women  Cruelty by Husband or his Relatives  \
# ...

# %%
df.shape
# Out:
# (9017, 10)

# %%
df.columns
# Out:
# Index(['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
#        'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
#        'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
#        'Importation of Girls'],
#       dtype='object')

# %%
df.isnull()
# Out:
#       STATE/UT  DISTRICT   Year   Rape  Kidnapping and Abduction  \
# 0        False     False  False  False                     False
# 1        False     False  False  False                     False
# 2        False     False  False  False                     False
# 3        False     False  False  False                     False
# 4        False     False  False  False                     False
# ...        ...       ...    ...    ...                       ...
# 9012     False     False  False  False                     False
# 9013     False     False  False  False                     False
# 9014     False     False  False  False                     False
# 9015     False     False  False  False                     False
# 9016     False     False  False  False                     False
#
#       Dowry Deaths  Assault on women with intent to outrage her modesty  \
# 0            False                                              False
# ...

# %%
features = ['STATE/UT', 'DISTRICT', 'Year', 'Rape', 'Kidnapping and Abduction',
       'Dowry Deaths', 'Assault on women with intent to outrage her modesty',
       'Insult to modesty of Women', 'Cruelty by Husband or his Relatives',
       'Importation of Girls']

# %%
for feature in features:
    null_check = pd.isnull(df[feature])
    print(null_check)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9012    False
# 9013    False
# 9014    False
# 9015    False
# 9016    False
# Name: STATE/UT, Length: 9017, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9012    False
# 9013    False
# 9014    False
# 9015    False
# 9016    False
# Name: DISTRICT, Length: 9017, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9012    False
# 9013    False
# 9014    False
# 9015    False
# 9016    False
# Name: Year, Length: 9017, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9012    False
# 9013    False
# 9014    False
# 9015    False
# 9016    False
# Name: Rape, Length: 9017, dtype: bool
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 9012    False
# 9013    False
# ...

# %%
df = df.dropna()
df.shape
# Out:
# (9017, 10)

# %%
df['DISTRICT'].unique()
# Out:
# array(['ADILABAD', 'ANANTAPUR', 'CHITTOOR', 'CUDDAPAH', 'EAST GODAVARI',
#        'GUNTAKAL RLY.', 'GUNTUR', 'HYDERABAD CITY', 'KARIMNAGAR',
#        'KHAMMAM', 'KRISHNA', 'KURNOOL', 'MAHABOOBNAGAR', 'MEDAK',
#        'NALGONDA', 'NELLORE', 'NIZAMABAD', 'PRAKASHAM', 'RANGA REDDY',
#        'SECUNDERABAD RLY.', 'SRIKAKULAM', 'VIJAYAWADA', 'VIJAYAWADA RLY.',
#        'VISAKHA RURAL', 'VISAKHAPATNAM', 'VIZIANAGARAM', 'WARANGAL',
#        'WEST GODAVARI', 'TOTAL', 'CHANGLANG', 'DIBANG VALLEY',
#        'KAMENG EAST', 'KAMENG WEST', 'LOHIT', 'PAPUM PARE', 'SIANG EAST',
#        'SIANG UPPER', 'SIANG WEST', 'SUBANSIRI LOWER', 'SUBANSIRI UPPER',
#        'TAWANG', 'TIRAP', 'BARPETA', 'BONGAIGAON', 'C.I.D.', 'CACHAR',
#        'DARRANG', 'DHEMAJI', 'DHUBRI', 'DIBRUGARH', 'G.R.P.', 'GOALPARA',
#        'GOLAGHAT', 'GUWAHATI CITY', 'HAILAKANDI', 'JORHAT', 'KAMRUP',
#        'KARBI ANGLONG', 'KARIMGANJ', 'KOKRAJHAR', 'LAKHIMPUR', 'MORIGAON',
# ...

# %%
df['Rape'].unique()
# Out:
# array([  50,   23,   27,   20,    0,   54,   37,   56,   47,   29,   59,
#          35,   46,   21,   19,   72,    8,   25,    1,   12,   13,   53,
#          61,  871,    2,    9,    5,    4,   33,   28,   45,   48,   42,
#          43,   30,   24,   14,   64,   51,    3,   41,  817,   93,   16,
#          34,   10,   22,    6,   11,   44,   73,   40,    7,   15,   39,
#         888,   17,   69,  144,   36,  104,   58,  145,  959,   18,   26,
#         286,   32,   31,   38,  398,  124,  169,  567,  293,   55,   71,
#          63,   57,  562,   87,   95,  106,   65,   66,   78,   68,   84,
#         108,   70,   79,  141,   52,   90,   86,  112, 2851,  127,   81,
#        1302,   77,  790,  298,   67, 1049,  423,  102,   83,   62,   85,
#        1958,   74,  709,  381,  103,   99,   49, 1002,   60,  970,  101,
#        1040,  132,  159,  142,  992,  267,  361,  137,  192,   76,  797,
#         292,  499,  115,   98,   82,   97,  148,   80,   88,  136,  114,
# ...

# %%
df_crime = df.groupby('Assault on women with intent to outrage her modesty').size().reset_index(name = 'Numbers')
df_crime
# Out:
#      Assault on women with intent to outrage her modesty  Numbers
# 0                                                    0        571
# 1                                                    1        220
# 2                                                    2        232
# 3                                                    3        184
# 4                                                    4        195
# ..                                                 ...        ...
# 548                                               6690          1
# 549                                               6772          1
# 550                                               6848          1
# 551                                               7063          1
# 552                                               7118          1
#
# [553 rows x 2 columns]

# %%
plt.figure(figsize = (8, 5))
plt.xlabel('Assault on women with intent to outrage her modesty')
plt.ylabel('Numbers')
x = df_crime('Assault on women with intent to outrage her modesty')
y = df_crime('Numbers')
plt.bar(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 4
#       2 plt.xlabel('Assault on women with intent to outrage her modesty')
#       3 plt.ylabel('Numbers')
# ----> 4 x = df_crime('Assault on women with intent to outrage her modesty')
#       5 y = df_crime('Numbers')
#       6 plt.bar(x, y)
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
data = {'Rape': [1, 0, 1, 0, 1]}
df = pd.DataFrame(data)


df_Rape = df.groupby('Rape').size().reset_index(name='Numbers')

print(df_Rape)
# Out:
#    Rape  Numbers
# 0     0        2
# 1     1        3

# %%
import matplotlib.pyplot as plt

x_values = [1, 2, 3, 4, 5]
y_values = [10, 20, 15, 25, 30]

plt.figure(figsize=(8, 5))
plt.plot(x_values, y_values, marker='o')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sample Plot')
plt.grid(True)
plt.show()

# %%
import seaborn as sns
sns.displot(df['Rape'], kde=True, bins=10)

# %%
df_min = df['Rape'].min()
df_max = df['Rape'].max()
print(df_min, df_max)
# Out:
# 0 1

# %%
sns.boxplot( df['Rape'])
# Out:
# <Axes: >

# %%
q_1 = df['Rape'].quantile(0.25)
q_3 = df['Rape'].quantile(0.75)
iqr = q_3 - q_1
iqr
lower = q_1 - 1.5 * iqr
upper = q_3 + 1.5 * iqr

# %%
import numpy as np
upper_array = np.where(df['Rape'] >= upper)[0]
lower_array = np.where(df['Rape'] <= lower)[0]

# %%
df.shape
# Out:
# (5, 1)
